# %% [markdown]
# ## Python IO与档案处理

# %%
f =#用open函数创建文档f，f为创建一个tmp.txt文本文件，当前f操作模式为w(r表示读取，a表示增加)
#f向tmp.txt文件写入"hello world"
#关闭f对象

# %%
###利用with函数使得不需要调用close关闭f

#利用with导入open函数，创建tmp.txt文本文件，并命名为f文档，文件当前操作模式为w
    #f向tmp.txt文件写入"hello world" 且要求输完hello后换行输入world

# %%
###打印输出文当里面的数据

#利用with导入open函数，创建tmp.txt文本文件，并命名为f文档，文档当前操作模式为r
    #f进行读取操作，获得tmp.txt文件里的数据，并将所有数据一次性当前输出打印出来
# Out:
# hello
# world

# %%
###按行打印输出文档里面的数据
with open('tmp.txt', 'r') as f:
    #利用for循环与f的readlines()遍历文档里面每一行数据
        #打印每一行数据，并利用strip()将换行符或空格删除掉
# Out:
# hello
# world

# %% [markdown]
# ## 处理CSV, Excel格式资料

# %%
 #用with导入open函数，将Population.csv的文件读取进来，encoding为UTF-8,读取进来的文档命名为f
    #利用for循环与f的readlines()遍历文档里面每一行数据
        #打印输出显示每行数据
# Out:
# ﻿指标,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2008年,2007年,2006年
#
# 年末总人口(万人),137462,136782,136072,135404,134735,134091,133450,132802,132129,131448
#
# 男性人口(万人),70414,70079,69728,69395,69068,68748,68647,68357,68048,67728
#
# 女性人口(万人),67048,66703,66344,66009,65667,65343,64803,64445,64081,63720
#
# 城镇人口(万人),77116,74916,73111,71182,69079,66978,64512,62403,60633,58288
#
# 乡村人口(万人),60346,61866,62961,64222,65656,67113,68938,70399,71496,73160

# %%
#导入pandas类库
df = #利用pandas的read_csv读取Population.csv文件
#输出显示df
# Out:
#           指标   2015年   2014年   2013年   2012年   2011年   2010年   2009年   2008年  \
# 0  年末总人口(万人)  137462  136782  136072  135404  134735  134091  133450  132802
# 1   男性人口(万人)   70414   70079   69728   69395   69068   68748   68647   68357
# 2   女性人口(万人)   67048   66703   66344   66009   65667   65343   64803   64445
# 3   城镇人口(万人)   77116   74916   73111   71182   69079   66978   64512   62403
# 4   乡村人口(万人)   60346   61866   62961   64222   65656   67113   68938   70399
#
#     2007年   2006年
# 0  132129  131448
# 1   68048   67728
# 2   64081   63720
# 3   60633   58288
# 4   71496   73160

# %%
import pandas
df = #利用pandas的read_excel读取GD.xls文件
#输出显示df
# Out:
#             指标     2015年     2014年     2013年     2012年     2011年     2010年  \
# 0    国民总收入(亿元)  686181.5  644791.1  590422.4  539116.5  484753.2  411265.2
# 1   国内生产总值(亿元)  689052.1  643974.0  595244.4  540367.4  489300.6  413030.3
# 2  第一产业增加值(亿元)   60862.1   58343.5   55329.1   50902.3   46163.1   39362.6
# 3  第二产业增加值(亿元)  282040.3  277571.8  261956.1  244643.3  227038.8  191629.8
# 4  第三产业增加值(亿元)  346149.7  308058.6  277959.3  244821.9  216098.6  182038.0
# 5  人均国内生产总值(元)   50251.0   47203.0   43852.0   40007.0   36403.0   30876.0
#
#       2009年     2008年     2007年     2006年
# 0  348498.5  321500.5  270844.0  219028.5
# 1  349081.4  319515.5  270232.3  219438.5
# 2   34161.8   32753.2   27788.0   23317.0
# 3  160171.7  149956.6  126633.6  104361.8
# 4  154747.9  136805.8  115810.7   91759.7
# 5   26222.0   24121.0   20505.0   16738.0

# %% [markdown]
# ## 处理JSON, XML格式资料

# %%
 #利用with open导入jd.json文件并命名为f
    #f调用read()读取数据并将结果赋值为jd
#查看jd

# %%
###将以上的jd文档转换成字典

#导入json库
dic = #利用json的loads导入jd并赋值给dic变量
#输出显示dic
#用shop代表dic里的每一个元素， for循环遍历dic
    #输出打印每一个shop里key为“shop_name”“shop_brief”的值
# Out:
# [{'business_category': '车载配件 电脑、办公 路由器 手机配件 手机保护套 电脑整机 蓝牙耳机 交换机 手机存储卡 智能手表 手机耳机 数码 网卡 充电器/数据线 充电器 拍照配件 手机通讯 网络配件 对讲机 苹果周边 平板电脑 网络产品 手机饰品 智能设备 智能手环 便携/无线音响 4G/3G上网 创意配件 数据线 电池/移动电源 手机电池 手机支架 iPhone 配件 网络盒子 特殊商品 手机 移动电源 平板电脑配件 手机贴膜',
#   'cid1': 9987,
#   'icon': 0,
#   'industry_effective_score': 963,
#   'industry_service_score': 971,
#   'industry_total_score': 974,
#   'main_brand': '华为（HUAWEI）',
#   'pic_url': '',
#   'shop_brief': '华为官方旗舰店',
#   'shop_id': 1000004259,
#   'shop_logo': '//img30.360buyimg.com/popshop/jfs/t1630/279/556645620/9702/375b1235/5595eb88N0f86a9de.jpg',
#   'shop_name': '华为官方旗舰店',
#   'shop_score': 651,
#   'shop_type': 28,
#   'summary': '',
#   'txt_weight': 0,
#   'vender_effective_score': 1000,
#   'vender_id': 1000004259,
#   'vender_service_score': 1000,
#   'vender_total_score': 1000,
#   'vender_type': 1,
#   'vender_ware_score': 1000,
#   'weight': 0},
#  {'business_category': '手机通讯 手机配件 创意配件 手机',
#   'cid1': 9987,
#   'icon': 0,
# ...

# %%
#利用json的dumps函数将上面的dic转换成json类型

# %%
#导入pandas类库
df = #利用padndas的read_json函数将jd.json文件导入转换为html表格方式 
#利用head()查看前5条记录
# Out:
#                                    business_category  cid1  icon  \
# 0  车载配件 电脑、办公 路由器 手机配件 手机保护套 电脑整机 蓝牙耳机 交换机 手机存储卡 ...  9987     0
# 1                                  手机通讯 手机配件 创意配件 手机  9987     0
# 2                                  手机通讯 手机配件 创意配件 手机  9987     0
# 3                                  手机通讯 手机配件 创意配件 手机  9987     0
# 4                         手机通讯 对讲机 手机配件 创意配件 特殊商品 手机  9987     0
#
#    industry_effective_score  industry_service_score  industry_total_score  \
# 0                       963                     971                   974
# 1                       954                     954                   954
# 2                       954                     954                   954
# 3                       954                     954                   954
# 4                       954                     954                   954
#
#                                           main_brand  \
# 0                                         华为（HUAWEI）
# ...

# %%
#导入xml的etree类库下的ElementTree并重命名为ET
tree = #利用ET的parse函数对weather.xml文件进行解析转换，并将结果命名为treee

# %%
root = #利用getroot获得tree的根，并将获取结果命名为root
#查看root
# Out:
# <Element 'china' at 0x0000001A45737688>

# %%
#用city代表树的每一个结点，利用root.iter函数遍历结点名称为city的所有树结点
    #打印输出每个树结点的cityname和tem1属性值
# Out:
# 哈尔滨 7
# 长春 9
# 沈阳 8
# 海口 19
# 呼和浩特 7
# 乌鲁木齐 2
# 拉萨 2
# 西宁 0
# 银川 8
# 兰州 7
# 石家庄 12
# 郑州 13
# 武汉 16
# 长沙 18
# 济南 14
# 南京 13
# 合肥 14
# 太原 10
# 西安 11
# 成都 12
# 昆明 11
# 贵阳 14
# 杭州 12
# 福州 12
# 南昌 15
# 广州 16
# 南宁 19
# 北京 12
# 天津 14
# 上海 13
# 重庆 17
# 香港 18
# 澳门 18
# 台北 17
# 西沙 24
# 南沙 25
# 钓鱼岛 18
